# %% [markdown]
# <h1><center><font size="6">The Clash of Classifiers</font></center></h1>
#
# <h2><center><font size="5">Where Classifiers Clash, Intelligence Reigns!</font></center></h2>
#
# <br>
#
#
# Created by:
# Tirana Noor Fatyanosa

# %% [markdown]
# # <a id='0'>Content</a>
#
# - <a href='#intro'>Introduction</a>
# - <a href='#create-kaggle'>Create Kaggle Account</a>
# - <a href='#join'>Join the Competition</a>
# - <a href='#create-import'>Create and import notebook</a>
# - <a href='#data-prep'>Data Preparation</a>
#  - <a href='#import-data'>Import datasets</a>
# - <a href='#explore'>Data exploration</a>
#  - <a href='#missing'>Check for missing data</a>
# - <a href='#preprocess'>Data preprocessing</a>
#  - <a href='#impute'>Imputation of missing data</a>
#  - <a href='#transform'>Data Transformation</a>
# - <a href='#model'>Build predictive model</a>
#  - <a href='#split'>Split the data</a>
#  - <a href='#baseline'>Build a baseline model</a>
#  - <a href='#submission'>Make a submission</a>
# - <a href='#other-model'>Try other models</a>
# - <a href='#improve'>How to improve</a>

# %% [markdown]
# # <a id='intro'>Introduction</a>
#
# This Kernel will take you through the process of **analyzing the data**, creation of a **baseline model**, and, at the end, **submission** of the best solution found.
#
# The dataset used for this tutorial is the **Horse Health Prediction** dataset.
#
#
# <a href="#0"><font size="1">Go to top</font></a>

# %% [markdown]
# <!-- <h2><center><font size="4">Dataset: Predict Health Outcomes of Horses</font></center></h2> -->
#
# <br>
#
# <img src="https://assets-global.website-files.com/5cc60ba2b2ea2ebc993540be/6595212de1741f3418c332d4_07-Horse.webp" width="1000"></img>

# %% [markdown]
# # <a id='create-kaggle'>Create Kaggle Account</a>
#
#
# Before starting, we need to make few preparation. First one, is making Kaggle account.
#
# <h3><font size="4">Step 1: Create a Kaggle Account</font></h3>
# Go to Kaggle's homepage.
#
# https://www.kaggle.com/
#
# <h3><font size="4">Step 2: Register</font></h3>
# Click on the "Register" button in the upper right corner of the page.
#
# You will have several options for signing up:
# Sign up with Google/Facebook/Email.
#
# <a href="#0"><font size="1">Go to top</font></a>

# %% [markdown]
# # <a id='join'>Join the competition</a>
#
# <h3><font size="4">Step 1: Load to the competition</font></h3>
# Go to the following link.
#
# https://bit.ly/mkpdai
#
# <h3><font size="4">Step 2: Join the competition</font></h3>
# Now, you will join the competition by clicking the "Join Competititon" link.
# If you decide to accept the rules, click on the “I Understand and Accept” button at the top of the page.
#
# ![](https://i.imgur.com/8DQjFuN.png)
#
#
# <a href="#0"><font size="1">Go to top</font></a>

# %% [markdown]
# # <a id='create-import'>Create and import notebook</a>
#
# <h3><font size="4">Step 1: Create a new notebook</font></h3>
#
# Go to the Code tab and write your own notebooks to work with the data, through the “New Notebook” button. (If you click on this now and have not yet accepted the competition rules, you’ll first be prompted to read and accept the rules.)
#
# ![](https://i.imgur.com/CD8DRYq.png)
#
#
# <h3><font size="4">Step 2: Download the example notebook</font></h3>
#
# Download notebook from the following link.
#
#
# <h3><font size="4">Step 3: Import the notebook</font></h3>
#
# Go to File, then click Import Notebook-> choose the .ipynb file from your device and upload
#
# <a href="#0"><font size="1">Go to top</font></a>

# %% [markdown]
# # <a id='data-prep'>Data Preparation</a>
#
#
# <a href="#0"><font size="1">Go to top</font></a>

# %% [markdown]
# Dari sumber dataset : [Horse Colic](https://www.kaggle.com/datasets/uciml/horse-colic/data)
#
# Didapatkan informasi
#
# 1: surgery?
# 1 = Yes, it had surgery
# 2 = It was treated without surgery
#
# 2: Age
# 1 = Adult horse
# 2 = Young (< 6 months)
#
# 3: Hospital Number
# - numeric id
# - the case number assigned to the horse (may not be unique if the horse is treated > 1 time)
#
# 4: rectal temperature
# - linear
# - in degrees celsius.
# - An elevated temp may occur due to infection.
# - temperature may be reduced when the animal is in late shock
# - normal temp is 37.8
# - this parameter will usually change as the problem progresses, eg. may start out normal, then become elevated because of the lesion, passing back through the normal range as the horse goes into shock
# 5: pulse
# - linear
# - the heart rate in beats per minute
# - is a reflection of the heart condition: 30 -40 is normal for adults
# - rare to have a lower than normal rate although athletic horses may have a rate of 20-25
# - animals with painful lesions or suffering from circulatory shock may have an elevated heart rate
#
# 6: respiratory rate
# - linear
# - normal rate is 8 to 10
# - usefulness is doubtful due to the great fluctuations
#
# 7: temperature of extremities
# - a subjective indication of peripheral circulation
# - possible values:
# 1 = Normal
# 2 = Warm
# 3 = Cool
# 4 = Cold
# - cool to cold extremities indicate possible shock
# - hot extremities should correlate with an elevated rectal temp.
#
# 8: peripheral pulse
# - subjective
# - possible values are:
# 1 = normal
# 2 = increased
# 3 = reduced
# 4 = absent
# - normal or increased p.p. are indicative of adequate circulation while reduced or absent indicate poor perfusion
#
# 9: mucous membranes
# - a subjective measurement of colour
# - possible values are:
# 1 = normal pink
# 2 = bright pink
# 3 = pale pink
# 4 = pale cyanotic
# 5 = bright red / injected
# 6 = dark cyanotic
# - 1 and 2 probably indicate a normal or slightly increased circulation
# - 3 may occur in early shock
# - 4 and 6 are indicative of serious circulatory compromise
# - 5 is more indicative of a septicemia
#
# 10: capillary refill time
# - a clinical judgement. The longer the refill, the poorer the circulation
# - possible values
# 1 = < 3 seconds
# 2 = >= 3 seconds
#
# 11: pain - a subjective judgement of the horse's pain level
# - possible values:
# 1 = alert, no pain
# 2 = depressed
# 3 = intermittent mild pain
# 4 = intermittent severe pain
# 5 = continuous severe pain
# - should NOT be treated as a ordered or discrete variable!
# - In general, the more painful, the more likely it is to require surgery
# - prior treatment of pain may mask the pain level to some extent
#
# 12: peristalsis
# - an indication of the activity in the horse's gut. As the gut becomes more distended or the horse becomes more toxic, the activity decreases
# - possible values:
# 1 = hypermotile
# 2 = normal
# 3 = hypomotile
# 4 = absent
#
# 13: abdominal distension
# - An IMPORTANT parameter.
# - possible values
# 1 = none
# 2 = slight
# 3 = moderate
# 4 = severe
# - an animal with abdominal distension is likely to be painful and have reduced gut motility.
# - a horse with severe abdominal distension is likely to require surgery just tio relieve the pressure
#
# 14: nasogastric tube
# - this refers to any gas coming out of the tube
# - possible values:
# 1 = none
# 2 = slight
# 3 = significant
# - a large gas cap in the stomach is likely to give the horse discomfort
#
# 15: nasogastric reflux
# - possible values
# 1 = none
# 2 = > 1 liter
# 3 = < 1 liter
# - the greater amount of reflux, the more likelihood that there is some serious obstruction to the fluid passage from the rest of the intestine
#
# 16: nasogastric reflux PH
# - linear
# - scale is from 0 to 14 with 7 being neutral
# - normal values are in the 3 to 4 range
#
# 17: rectal examination - feces
# - possible values
# 1 = normal
# 2 = increased
# 3 = decreased
# 4 = absent
# - absent feces probably indicates an obstruction
#
# 18: abdomen
# - possible values
# 1 = normal
# 2 = other
# 3 = firm feces in the large intestine
# 4 = distended small intestine
# 5 = distended large intestine
# - 3 is probably an obstruction caused by a mechanical impaction and is normally treated medically
# - 4 and 5 indicate a surgical lesion
#
# 19: packed cell volume
# - linear
# - the # of red cells by volume in the blood
# - normal range is 30 to 50. The level rises as the circulation becomes compromised or as the animal becomes dehydrated.
#
# 20: total protein
# - linear
# - normal values lie in the 6-7.5 (gms/dL) range
# - the higher the value the greater the dehydration
#
# 21: abdominocentesis appearance
# - a needle is put in the horse's abdomen and fluid is obtained from
# the abdominal cavity
# - possible values:
# 1 = clear
# 2 = cloudy
# 3 = serosanguinous
# - normal fluid is clear while cloudy or serosanguinous indicates a compromised gut
#
# 22: abdomcentesis total protein
# - linear
# - the higher the level of protein the more likely it is to have a compromised gut. Values are in gms/dL
#
# 23: outcome
# - what eventually happened to the horse?
# - possible values:
# 1 = lived
# 2 = died
# 3 = was euthanized
#
# 24: surgical lesion?
# - retrospectively, was the problem (lesion) surgical?
# - all cases are either operated upon or autopsied so that this value and the lesion type are always known
# - possible values:
# 1 = Yes
# 2 = No
#
# 25, 26, 27: type of lesion
# - first number is site of lesion
# 1 = gastric
# 2 = sm intestine
# 3 = lg colon
# 4 = lg colon and cecum
# 5 = cecum
# 6 = transverse colon
# 7 = retum/descending colon
# 8 = uterus
# 9 = bladder
# 11 = all intestinal sites
# 00 = none
# - second number is type
# 1 = simple
# 2 = strangulation
# 3 = inflammation
# 4 = other
# - third number is subtype
# 1 = mechanical
# 2 = paralytic
# 0 = n/a
# - fourth number is specific code
# 1 = obturation
# 2 = intrinsic
# 3 = extrinsic
# 4 = adynamic
# 5 = volvulus/torsion
# 6 = intussuption
# 7 = thromboembolic
# 8 = hernia
# 9 = lipoma/slenic incarceration
# 10 = displacement
# 0 = n/a
# 28: cp_data
# - is pathology data present for this case?
# 1 = Yes
# 2 = No
# - this variable is of no significance since pathology data is not included or collected for these cases

# %% [markdown]
# <a href="#0"><font size="1">Go to top</font></a>
#
#
# ## <a id='22'>Load the data</a>
#
# There are **train** and **test** data as well as an example **submission** file.
#
# Let's load the **train** and **test** data.
#
#
# <a href="#0"><font size="1">Go to top</font></a>

# %%
# Write and run the above code in the following code section.
import pandas as pd

train = pd.read_csv("/kaggle/input/competitions/mkpdai-predict-health-outcomes-of-horses/train.csv")
test = pd.read_csv("/kaggle/input/competitions/mkpdai-predict-health-outcomes-of-horses/test.csv")
train.head()
# Out:
#    id surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0   0     yes  adult           530001         38.1  132.0              24.0
# 1   1     yes  adult           533836         37.5   88.0              12.0
# 2   2     yes  adult           529812         38.3  120.0              28.0
# 3   3     yes  adult          5262541         37.1   72.0              30.0
# 4   4      no  adult          5299629         38.0   52.0              48.0
#
#   temp_of_extremities peripheral_pulse mucous_membrane  ...  \
# 0                cool          reduced   dark_cyanotic  ...
# 1                cool           normal   pale_cyanotic  ...
# 2                cool          reduced       pale_pink  ...
# 3                cold          reduced       pale_pink  ...
# 4              normal           normal     normal_pink  ...
#
#   packed_cell_volume total_protein abdomo_appearance abdomo_protein  \
# 0               57.0           8.5     serosanguious            3.4
# ...

# %% [markdown]
# <a href="#0"><font size="1">Go to top</font></a>
#
# # <a id='explore'>Data exploration</a>
#
# We check the shape of train and test dataframes and also show a selection of rows, to have an initial image of the data.

# %%
# Write and run the above code in the following code section.
train.sample(5).head()
# Out:
#       id surgery    age  hospital_number  rectal_temp  pulse  \
# 101  101      no  adult           534280         38.3   52.0
# 929  929     yes  adult           528570         37.5   48.0
# 344  344      no  adult           528548         38.1   54.0
# 844  844     yes  adult           533836         37.2   88.0
# 257  257     yes  adult           529667         39.0   64.0
#
#      respiratory_rate temp_of_extremities peripheral_pulse mucous_membrane  \
# 101              20.0                 NaN          reduced   pale_cyanotic
# 929              28.0                cool          reduced   pale_cyanotic
# 344              28.0              normal           normal       pale_pink
# 844              48.0                cool          reduced     normal_pink
# 257              36.0                warm           normal       pale_pink
#
#      ... packed_cell_volume total_protein abdomo_appearance abdomo_protein  \
# ...

# %%
# Write and run the above code in the following code section.
test.sample(5).head()
# Out:
#        id surgery    age  hospital_number  rectal_temp  pulse  \
# 649  1884      no  adult           529475         37.6   52.0
# 438  1673      no  adult           530239         38.6   56.0
# 466  1701     yes  adult           534787         38.0   80.0
# 294  1529     yes  adult           530478         37.1  100.0
# 778  2013      no  adult           528800         38.1   84.0
#
#      respiratory_rate temp_of_extremities peripheral_pulse mucous_membrane  \
# 649              18.0                warm           normal     bright_pink
# 438              12.0              normal           normal     normal_pink
# 466              24.0                cool           normal     normal_pink
# 294              30.0                cool          reduced   pale_cyanotic
# 778              40.0                cool          reduced      bright_red
#
#      ...        abdomen packed_cell_volume total_protein abdomo_appearance  \
# ...

# %%
# Write and run the above code in the following code section.
print("Train: rows:{} cols:{}".format(train.shape[0], train.shape[1]))
print("Test: rows:{} cols:{}".format(test.shape[0], test.shape[1]))
# Out:
# Train: rows:1235 cols:29
# Test: rows:824 cols:28

# %% [markdown]
# Both **train** and **test** files contains 28 features.
#
# The **train** data has as well the target value, **Outcome**.
#
# It is important, before going to create a model, to have a good understanding of the data. We will therefore explore the various features.

# %%
# Write and run the above code in the following code section.

train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1235 entries, 0 to 1234
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     1235 non-null   int64
#  1   surgery                1235 non-null   object
#  2   age                    1235 non-null   object
#  3   hospital_number        1235 non-null   int64
#  4   rectal_temp            1235 non-null   float64
#  5   pulse                  1235 non-null   float64
#  6   respiratory_rate       1235 non-null   float64
#  7   temp_of_extremities    1196 non-null   object
#  8   peripheral_pulse       1175 non-null   object
#  9   mucous_membrane        1214 non-null   object
#  10  capillary_refill_time  1229 non-null   object
#  11  pain                   1191 non-null   object
#  12  peristalsis            1215 non-null   object
#  13  abdominal_distention   1212 non-null   object
# ...

# %%
# Write and run the above code in the following code section.
train.describe()
# Out:
#               id  hospital_number  rectal_temp        pulse  respiratory_rate  \
# count  1235.0000     1.235000e+03  1235.000000  1235.000000       1235.000000
# mean    617.0000     9.545004e+05    38.202186    79.574089         30.054251
# std     356.6581     1.356403e+06     0.788668    29.108638         16.452066
# min       0.0000     5.213990e+05    35.400000    30.000000          8.000000
# 25%     308.5000     5.288000e+05    37.800000    53.000000         18.000000
# 50%     617.0000     5.297770e+05    38.200000    76.000000         28.000000
# 75%     925.5000     5.341450e+05    38.600000   100.000000         36.000000
# max    1234.0000     5.305129e+06    40.800000   184.000000         96.000000
#
#        nasogastric_reflux_ph  packed_cell_volume  total_protein  \
# count            1235.000000         1235.000000    1235.000000
# mean                4.382591           49.602429      21.388016
# std                 1.937357           10.535800      26.676453
# ...

# %% [markdown]
# ## <a id='missing'>Check for missing data</a>
#
# Let's create a function that check for missing data in the two datasets (train and test).

# %%
# Write and run the above code in the following code section.
def missing_data(data):
    total = data.isnull().sum().sort_values(ascending = False)
    percent = (data.isnull().sum()/data.isnull().count()*100).sort_values(ascending = False)
    return pd.concat([total,percent], axis=1, keys=['Total', 'Percent'])

missing_data(train)
# Out:
#                        Total    Percent
# abdomen                  213  17.246964
# rectal_exam_feces        190  15.384615
# nasogastric_tube          80   6.477733
# peripheral_pulse          60   4.858300
# abdomo_appearance         48   3.886640
# pain                      44   3.562753
# temp_of_extremities       39   3.157895
# abdominal_distention      23   1.862348
# nasogastric_reflux        21   1.700405
# mucous_membrane           21   1.700405
# peristalsis               20   1.619433
# capillary_refill_time      6   0.485830
# rectal_temp                0   0.000000
# respiratory_rate           0   0.000000
# pulse                      0   0.000000
# hospital_number            0   0.000000
# id                         0   0.000000
# surgery                    0   0.000000
# age                        0   0.000000
# packed_cell_volume         0   0.000000
# nasogastric_reflux_ph      0   0.000000
# total_protein              0   0.000000
# ...

# %%
# Write and run the above code in the following code section.
missing_data(test)
# Out:
#                        Total    Percent
# abdomen                  154  18.689320
# rectal_exam_feces        125  15.169903
# nasogastric_tube          64   7.766990
# peripheral_pulse          47   5.703883
# temp_of_extremities       35   4.247573
# abdomo_appearance         31   3.762136
# pain                      29   3.519417
# abdominal_distention      22   2.669903
# peristalsis               19   2.305825
# nasogastric_reflux        14   1.699029
# mucous_membrane           13   1.577670
# capillary_refill_time      6   0.728155
# pulse                      0   0.000000
# rectal_temp                0   0.000000
# respiratory_rate           0   0.000000
# hospital_number            0   0.000000
# id                         0   0.000000
# surgery                    0   0.000000
# age                        0   0.000000
# nasogastric_reflux_ph      0   0.000000
# packed_cell_volume         0   0.000000
# total_protein              0   0.000000
# ...

# %% [markdown]
# Both in **train** and **test** datasets, `Abdomen` has more than 17% missing.
#
# We will discuss, through this tutorial, the various possible methods to deal with missing data.

# %%
train['nasogastric_reflux'].unique()
# Out:
# array(['less_1_liter', 'more_1_liter', 'none', nan, 'slight'],
#       dtype=object)

# %%
train['capillary_refill_time'].unique()
# Out:
# array(['more_3_sec', 'less_3_sec', nan, '3'], dtype=object)

# %%
print(train['peristalsis'].value_counts(dropna=False))
# Out:
# peristalsis
# hypomotile       664
# absent           444
# normal            53
# hypermotile       53
# NaN               20
# distend_small      1
# Name: count, dtype: int64

# %%
print(train['nasogastric_reflux'].value_counts(dropna=False))
# Out:
# nasogastric_reflux
# more_1_liter    604
# none            331
# less_1_liter    278
# NaN              21
# slight            1
# Name: count, dtype: int64

# %%
print(train['rectal_exam_feces'].value_counts(dropna=False))
# Out:
# rectal_exam_feces
# absent           493
# decreased        269
# normal           233
# NaN              190
# increased         49
# serosanguious      1
# Name: count, dtype: int64

# %% [markdown]
# <a href="#0"><font size="1">Go to top</font></a>
#
# # <a id='preprocess'>Data preprocessing</a>

# %% [markdown]
# Saya membuat Feature Engineering dari Informasi Atribut sebelumnya. Lalu, seperti yang diketahui Variabel lesion merupakan kode medis yang terdiri dari beberapa digit dengan makna berbeda. Untuk menyederhanakan kompleksitas(mengurangi dimensionalitas dan menghindari sparsity) yang nantinya menggunakan onehot encoding, saya hanya memakai digit kedua (type of lesion) yang digunakan karena merepresentasikan jenis kondisi utama. Dari tipe tersebut, dilakukan penyederhanaan lebih lanjut dengan hanya mempertahankan kondisi strangulation (kode 2), karena memiliki tingkat keparahan paling tinggi serta relevansi yang kuat terhadap outcome pasien. Sementara itu, tipe kondisi lainnya digabungkan ke dalam satu kategori. sehingga hasilnya akan ditransformasikan menjadi variabel biner, yaitu : stranglutation = 1 dan other = 0.

# %%
def extract_lesion_features(df, col_name):

    s = df[col_name].astype(str).str.zfill(5) 

    df[f'{col_name}_type'] = ((df[col_name] // 1000) % 10)     

    df[f'{col_name}_is_strangulation'] = (df[f'{col_name}_type'] == 2).astype(int)
    return df

# %%
def feature_engineering(df):
    df = df.copy()

    # atur lesion code
    for col in ['lesion_1', 'lesion_2', 'lesion_3']:
        df = extract_lesion_features(df, col)

    df['has_strangulation'] = (
        df['lesion_1_is_strangulation'] |
        df['lesion_2_is_strangulation'] |
        df['lesion_3_is_strangulation']
    ).astype(int)

    # syarat
    df['temp_deviation'] = (df['rectal_temp'] - 37.8).abs()

    # ubah kategori yg berbeda dari informasi
    df['capillary_refill_time'] = df['capillary_refill_time'].replace({'3': 'more_3_sec'})
    df['nasogastric_reflux'] = df['nasogastric_reflux'].replace({'slight': 'less_1_liter'})
    df['peristalsis'] = df['peristalsis'].replace({'distend_small': 'hypomotile'})
    df['rectal_exam_feces'] = df['rectal_exam_feces'].replace({'serosanguious': 'absent'})

    # binary encoding
    df['surgery'] = (df['surgery'] == 'yes').astype(int)
    df['surgical_lesion'] = (df['surgical_lesion'] == 'yes').astype(int)
    df['age'] = (df['age'] == 'adult').astype(int)

    # binning
    df['pulse_severity'] = pd.cut(df['pulse'], bins=[0, 29, 40, 60, 200], labels=[0, 1, 2, 3], include_lowest=True).astype(float)
    df['protein_severity'] = pd.cut(df['total_protein'], bins=[0, 6, 7.5, 10, 100], labels=[0, 1, 2, 3], include_lowest=True).astype(float)

    # fe
    df['pulse_pcv_risk'] = df['pulse_severity'] * df['packed_cell_volume'] / 100
    df['pain_and_surgery'] = df['surgery'] * df['surgical_lesion'] 
    df['dehydration_index'] = df['packed_cell_volume'] * df['total_protein']
    df['critical_state'] = ((df['pain'] == 'depressed') & (df['peristalsis'] == 'absent')).astype(int)
    df['vital_stress'] = df['pulse'] * df['rectal_temp']
    
    # Referensi: PMC11415896
    df['gut_failure'] = (
        (df['peristalsis'] == 'absent') |
        (df['nasogastric_reflux'] == 'more_1_liter')
    ).astype(int)
    
    df['perfusion_failure'] = (
        (df['capillary_refill_time'] == 'more_3_sec') &
        (df['mucous_membrane'].isin(['pale_cyanotic', 'dark_cyanotic']))
        
    ).astype(int)
    # DROP
    df.drop(columns=['cp_data','lesion_1', 'lesion_2', 'lesion_3', 'id', 'hospital_number','rectal_temp','pulse','total_protein',
                    'respiratory_rate','lesion_1_type', 'lesion_2_type', 'lesion_3_type','lesion_1_is_strangulation', 'lesion_2_is_strangulation', 'lesion_3_is_strangulation'], inplace=True, errors='ignore')
    return df

# %%
train_fe = feature_engineering(train)
test_fe  = feature_engineering(test)

# %%
train_fe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1235 entries, 0 to 1234
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   surgery                1235 non-null   int64
#  1   age                    1235 non-null   int64
#  2   temp_of_extremities    1196 non-null   object
#  3   peripheral_pulse       1175 non-null   object
#  4   mucous_membrane        1214 non-null   object
#  5   capillary_refill_time  1229 non-null   object
#  6   pain                   1191 non-null   object
#  7   peristalsis            1215 non-null   object
#  8   abdominal_distention   1212 non-null   object
#  9   nasogastric_tube       1155 non-null   object
#  10  nasogastric_reflux     1214 non-null   object
#  11  nasogastric_reflux_ph  1235 non-null   float64
#  12  rectal_exam_feces      1045 non-null   object
#  13  abdomen                1022 non-null   object
# ...

# %% [markdown]
# ## <a id='baseline'>Build a baseline model</a>

# %%
# Write and run the above code in the following code section.
target = 'outcome'
train_Y = train_fe[target].values
train_X = train_fe.drop(columns=[target])

# %% [markdown]
# ## <a id='split'>Split the data</a>
#
# Let's split the training and validation set. We will use a 80-20 split.
# We also set the matrices for train and validation and the vectors with the target values.
# We define random state for reproducibility.

# %%
# Write and run the above code in the following code section.
from sklearn.model_selection import train_test_split

VALID_SIZE = 0.2
RANDOM_STATE = 2018

X_train, X_val, y_train, y_val = train_test_split(train_X,train_Y, test_size = VALID_SIZE, random_state=RANDOM_STATE, shuffle=True)

# %% [markdown]
# ## <a id='impute'>Imputation of missing data</a>
#
# We will use the most frequent value to impute all columns with missing data.

# %%
# Mapping ordinal
ordinal_mappings = {
    'temp_of_extremities': ['normal', 'warm', 'cool', 'cold'],
    'abdominal_distention': ['none', 'slight', 'moderate', 'severe'],
    'capillary_refill_time': ['less_3_sec', 'more_3_sec'],
    'peristalsis': ['hypermotile', 'normal', 'hypomotile', 'absent'],
    'nasogastric_tube': ['none', 'slight', 'significant'],
    'nasogastric_reflux': ['none', 'more_1_liter','less_1_liter'],
    'rectal_exam_feces': ['normal', 'increased', 'decreased', 'absent'],
    'abdomo_appearance': ['clear', 'cloudy', 'serosanguious']
}

all_mappings = {
    'peripheral_pulse': {
        'normal': 0, 'increased': 0, 'reduced': 1, 'absent': 1
    },
    'mucous_membrane': {
        'normal_pink': 0, 'bright_pink': 0, 'pale_pink': 1, 
         'pale_cyanotic': 2, 'dark_cyanotic': 2,'bright_red': 3
    }
}

# %%
# Write and run the above code in the following code section.
from sklearn.impute import SimpleImputer
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import FunctionTransformer
from imblearn.pipeline import Pipeline as ImbPipeline
from sklearn import set_config
from imblearn.over_sampling import SMOTENC
from catboost import CatBoostClassifier
from imblearn.pipeline import make_pipeline
from sklearn import set_config

cat_columns = X_train.select_dtypes(include=['object', 'category']).columns.tolist()
num_cols = X_train.select_dtypes(include=['float64','int64']).columns.tolist()
ordinal_cols = list(all_mappings.keys()) + list(ordinal_mappings.keys())
cat_cols = [col for col in cat_columns if col not in ordinal_cols]

set_config(transform_output="pandas")

def custom_mapper(df):
    # Jika input adalah NumPy Array (karena set_config default), ubah ke DataFrame
    if isinstance(df, np.ndarray):
        df = pd.DataFrame(df, columns=ordinal_cols)
    
    df_copy = df.copy()
    
    # Terapkan all_mappings
    for col, mapping in all_mappings.items():
        if col in df_copy.columns:
            df_copy[col] = df_copy[col].map(mapping)
    
    # Terapkan ordinal_mappings
    for col, urutan in ordinal_mappings.items():
        if col in df_copy.columns:
            map_index = {val: i for i, val in enumerate(urutan)}
            df_copy[col] = df_copy[col].map(map_index)
            
    return df_copy

# %% [markdown]
# ## Pipeline

# %%
selected_cols = [
    'num__vital_stress',
    'num__pulse_pcv_risk',
    'num__abdomo_protein',
    'num__nasogastric_reflux_ph',
    'num__dehydration_index',
    'num__surgical_lesion',
    'num__surgery',
    'num__age',
    'ord__abdomo_appearance',
    'num__protein_severity',
    'num__pain_and_surgery',
    'nom__pain_alert',
    'nom__pain_extreme_pain',
    'nom__pain_mild_pain',
    'nom__pain_severe_pain',
    'nom__abdomen_normal'
]

# %%
# Numerik
num_pipeline = ImbPipeline([
    ('imputer', SimpleImputer(strategy='median'))
])

# Semua Kolom Kategori
# ord
ordinal_transformer = ImbPipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('mapper', FunctionTransformer(custom_mapper))
])
# One-hot di ordinalkan dahulu
cat_pipeline_smote = ImbPipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('ordinal', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))
])

# Gabungkan
imputasi = ColumnTransformer([
   ('num', num_pipeline, num_cols),
   ('ord', ordinal_transformer, ordinal_cols),
   ('nom', cat_pipeline_smote, cat_cols)
])

#SMOTENC
n_num = len(num_cols)
n_ord = len(ordinal_cols)
n_cat = len(cat_cols)

cat_indices = list(range(n_num, n_num + n_ord + n_cat))
n_cat_indices = list(range(n_num + n_ord, n_num + n_ord + n_cat))

smote = SMOTENC(
    categorical_features=cat_indices,
    random_state=42
)

set_config(transform_output="default")

# One Hot kembali
OneHot_smote = ColumnTransformer([
    ('num', 'passthrough', list(range(n_num))),
    ('ord', 'passthrough', list(range(n_num, n_num + n_ord))),
    ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), n_cat_indices)
])

preprocessor = ImbPipeline([
   ('imputasi', imputasi),
   ('smote', smote),
   ('OneHot', OneHot_smote),
])

# Label encoder
le = LabelEncoder()

# %% [markdown]
# <a href="#0"><font size="1">Go to top</font></a>
#
# # <a id='model'>Build predictive model</a>
#
# Let's start with creation of the predictive models. We will create a very simple model for starting.

# %%
# Write and run the above code in the following code section.
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()

# %%
X_train.head()
# Out:
#      surgery  age temp_of_extremities peripheral_pulse mucous_membrane  \
# 638        0    1                cool              NaN             NaN
# 849        1    1                 NaN          reduced     normal_pink
# 691        1    1                cool          reduced     normal_pink
# 37         1    1                cool          reduced   pale_cyanotic
# 900        1    1              normal           normal       pale_pink
#
#     capillary_refill_time       pain peristalsis abdominal_distention  \
# 638            less_3_sec  mild_pain         NaN             moderate
# 849            less_3_sec  depressed  hypomotile               slight
# 691            more_3_sec  depressed  hypomotile             moderate
# 37             less_3_sec  mild_pain      absent             moderate
# 900            less_3_sec  mild_pain  hypomotile             moderate
#
#     nasogastric_tube  ... temp_deviation  pulse_severity protein_severity  \
# ...

# %%
# Write and run the above code in the following code section.
gnb.fit(X_train, y_train_encoded)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_57/1821304632.py in <cell line: 0>()
#       1 # Write and run the above code in the following code section.
# ----> 2 gnb.fit(X_train, y_train_encoded)
#
# NameError: name 'y_train_encoded' is not defined

# %%
# Write and run the above code in the following code section.
pred = gnb.predict(X_val)

# %% [markdown]
# <a href="#0"><font size="1">Go to top</font></a>
#
#
# ## <a id='52'>Evaluate the model</a>

# %%
# Write and run the above code in the following code section.
gnb.score(X_train, y_train_encoded)
acc = round(gnb.score(X_train, y_train_encoded)* 100,2)
print("Naive Bayes accuracy (train set:",acc)

# %%
# Write and run the above code in the following code section.
gnb.score(X_val, y_val_encoded)
acc = round(gnb.score(y_val, y_val_encoded)*100,2)
print("Naive Bayes accuracy (validation set):",acc)

# %% [markdown]
# The accuracy for the validation is much better than the accuracy for the training set.
# This means the model does not learn too well the training set, we are not overfitting (yet). The validation is better, i.e. we are generalizing well.

# %% [markdown]
# <a href="#0"><font size="1">Go to top</font></a>
#
#
# # <a id='other-model'>Try other models</a>

# %% [markdown]
# ### <a id='naive'>KNN</a>

# %%
# Write and run the above code in the following code section.
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
knn.fit(X_train, y_train_encoded)
pred = knn.predict(y_val)

acc_train = round(knn.score(X_train, y_train_encoded) * 100, 2)
print("KNN accuracy (train set):", acc_train)

acc_val = round(knn.score(y_val, y_val_encoded) * 100, 2)
print("KNN accuracy (validation set):", acc_val)

# %% [markdown]
# ## [](http://)<a id='decision_tree'>Decision Tree</a>

# %%
# Write and run the above code in the following code section.
# Write and run the above code in the following code section.
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()
dt.fit(X_train, y_train_encoded)
pred = dt.predict(y_val)

acc_train = round(dt.score(X_train, y_train_encoded) * 100, 2)
print("Decision Tree accuracy (train set):", acc_train)

acc_val = round(dt.score(y_val, y_val_encoded) * 100, 2)
print("Decision Tree accuracy (validation set):", acc_val)

# %% [markdown]
# ### <a id='random'>Random Forest</a>

# %%
# Write and run the above code in the following code section.
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf.fit(X_train, y_train_encoded)
preds = rf.predict(y_val)

acc_train = round(rf.score(X_train, y_train_encoded) * 100, 2)
print("Random Forest accuracy (train set):", acc_train)

acc_val = round(rf.score(y_val, y_val_encoded) * 100, 2)
print("Random Forest accuracy (validation set):", acc_val)

# %% [markdown]
# ### <a id='naive'>XGBoost</a>

# %%
# Write and run the above code in the following code section.
from xgboost import XGBClassifier

xgb = XGBClassifier()
xgb.fit(X_train, y_train_encoded)
pred = xgb.predict(y_val)

acc_train = round(xgb.score(X_train, y_train_encoded) * 100, 2)
print("XGBoost accuracy (train set):", acc_train)

acc_val = round(xgb.score(y_val, y_val_encoded) * 100, 2)
print("XGBoost accuracy (validation set):", acc_val)

# %% [markdown]
# <a href="#0"><font size="1">Go to top</font></a>
#
# # <a id='improve'>How to improve</a>

# %% [markdown]
# ## <a id='improve'>Hyperparameter Optimization</a>

# %% [markdown]
# ### KNN

# %%
# Write and run the above code in the following code section.

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train_encoded)
pred = knn.predict(y_val)

acc_train = round(knn.score(X_train, y_train_encoded) * 100, 2)
print("KNN (n=5) accuracy (train set):", acc_train)

acc_val = round(knn.score(y_val, y_val_encoded) * 100, 2)
print("KNN (n=5) accuracy (validation set):", acc_val)

# %% [markdown]
# ### Random Forest

# %%
# Write and run the above code in the following code section.
RFC_METRIC = 'gini'
NUM_ESTIMATORS = 100 
NO_JOBS = 4

rf = RandomForestClassifier(n_jobs = NO_JOBS, random_state=RANDOM_STATE,criterion=RFC_METRIC,n_estimators=NUM_ESTIMATORS,verbose=False)

rf.fit(X_train, y_train_encoded)
preds = rf.predict(y_val)

rf.score(train_l, y_train_encoded)
acc = round(rf.score(X_train, y_train_encoded)*100,2)
print("Random Forest accuracy (train set):", acc)

rf.score(y_val, y_val_encoded)
acc = round(rf.score(y_val, y_val_encoded)*100,2)
print("Random Forest accuracy (validation set):", acc)

# %%
# !pip install optuna

# %%
import optuna
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score
from xgboost import XGBClassifier
from sklearn.base import clone

# %% [markdown]
# # SMOTE

# %%
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import SMOTENC

# %%
X_res, y_train_resampled = preprocessor[:-1].fit_resample(X_train, y_train)

y_train_resampled_encoded = le.fit_transform(y_train_resampled)
y_val_encoded = le.transform(y_val)

# %%
# Melakukan tuning hyperparameter agar mendapat hasil model yang baik
def objective_xgb(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 200, 600),
        "max_depth": trial.suggest_int("max_depth", 3, 8),
    
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.1),
    
        "subsample": trial.suggest_float("subsample", 0.7, 1.0),
    
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.7, 1.0),
    
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 8),
    
        "gamma": trial.suggest_float("gamma", 0, 2),
    
        "reg_alpha": trial.suggest_float("reg_alpha", 0, 2),
    
        "reg_lambda": trial.suggest_float("reg_lambda", 0.5, 5),

        "objective": "multi:softprob",
        "num_class": 3,
        "random_state": 42,
        "n_jobs": -1
    }

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    f1_scores = []

    set_config(transform_output="default")
    
    for train_idx, val_idx in skf.split(X_train, y_train):
        # 1. Split data berdasarkan index fold
        X_tr, X_valid = X_train.iloc[train_idx].copy(), X_train.iloc[val_idx].copy()
        y_tr, y_valid = y_train[train_idx], y_train[val_idx]

        preprocessor_fold = clone(preprocessor)
    
        # 6. Gabungkan Numerik + Kategorikal (Hasil Akhir)
        X_tr_res, y_tr_resampled = preprocessor_fold[:-1].fit_resample(X_tr, y_tr)
        X_tr_final = preprocessor_fold.named_steps['OneHot'].fit_transform(X_tr_res)
        y_tr_res_encoded = le.transform(y_tr_resampled)
        
        X_val_temp = preprocessor_fold.named_steps['imputasi'].transform(X_valid)
        X_valid_final = preprocessor_fold.named_steps['OneHot'].transform(X_val_temp)
        y_val_res_encoded = le.transform(y_valid)

        #X_tr_selected = X_tr_final[selected_cols]
        #X_valid_selected = X_valid_final[selected_cols]

        model = XGBClassifier(**params,early_stopping_rounds=30,eval_metric="mlogloss")
        model.fit(X_tr_final, y_tr_res_encoded,eval_set=[(X_valid_final, y_val_res_encoded)],
            verbose=False)

        y_pred = model.predict(X_valid_final)
        f1_scores.append(f1_score(y_val_res_encoded, y_pred, average='macro'))

    return np.mean(f1_scores)

# %%
study_xgb = optuna.create_study(direction="maximize") # optuna akan mencari nilai objective(f1_scores) yang terbesar
study_xgb.optimize(objective_xgb, n_trials=50)  # menjalankan pencarian sebanyak 30 percobaan

# %%
#  Membuat model Random Forest dengan parameter terbaik yang didapat
best_xgb = XGBClassifier(
    **study_xgb.best_params,
    objective="multi:softprob",
    num_class=3,
    random_state=42,
    n_jobs=-1,
    early_stopping_rounds=30
)

# %%
# 2. Training: OneHot (belajar dari hasil SMOTE)
X_train_transformed = preprocessor.named_steps['OneHot'].fit_transform(X_res)

# 3. Validasi & Test: Lewati SMOTE, langsung Imputasi -> OneHot
# Panggil 'imputasi' langsung, JANGAN lewat preprocessor[:-1]
X_val_temp = preprocessor.named_steps['imputasi'].transform(X_val)
X_val_transformed = preprocessor.named_steps['OneHot'].transform(X_val_temp)

X_test_temp = preprocessor.named_steps['imputasi'].transform(test_fe)
X_test_transformed = preprocessor.named_steps['OneHot'].transform(X_test_temp)

set_config(transform_output="pandas")
column_names = preprocessor.named_steps['OneHot'].get_feature_names_out()

# %%
train_l = X_train_transformed
val_l   = X_val_transformed
test_l  = X_test_transformed

train_l_df = pd.DataFrame(train_l, columns=column_names)
val_l_df   = pd.DataFrame(val_l, columns=column_names)
test_l_df  = pd.DataFrame(test_l, columns=column_names)

# %%
best_xgb.fit(train_l_df, y_train_resampled_encoded,eval_set=[(val_l_df, y_val_encoded)], # Pantau data val
    verbose=False)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.749509005771888, device=None,
#               early_stopping_rounds=30, enable_categorical=False,
#               eval_metric=None, feature_types=None, feature_weights=None,
#               gamma=0.6131100134000275, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.07700890202591561,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=2, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=571, n_jobs=-1, num_class=3, ...)

# %%
y_train_pred = best_xgb.predict(train_l_df)
y_test_pred  = best_xgb.predict(val_l_df)

# %%
# melihat classification report di data train dan test
from sklearn.metrics import classification_report, confusion_matrix
print("=== TRAIN ===")
print(classification_report(y_train_resampled_encoded, y_train_pred, digits=4))

print("=== TEST ===")
print(classification_report(y_val_encoded, y_test_pred, digits=4))
# Out:
# === TRAIN ===
#               precision    recall  f1-score   support
#
#            0     0.8004    0.8475    0.8233       459
#            1     0.8452    0.8802    0.8623       459
#            2     0.8450    0.7603    0.8005       459
#
#     accuracy                         0.8293      1377
#    macro avg     0.8302    0.8293    0.8287      1377
# weighted avg     0.8302    0.8293    0.8287      1377
#
# === TEST ===
#               precision    recall  f1-score   support
#
#            0     0.6702    0.7875    0.7241        80
#            1     0.6731    0.6731    0.6731        52
#            2     0.7822    0.6870    0.7315       115
#
#     accuracy                         0.7166       247
#    macro avg     0.7085    0.7158    0.7096       247
# weighted avg     0.7229    0.7166    0.7168       247

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score
from sklearn.base import clone
from sklearn.utils.class_weight import compute_sample_weight, compute_class_weight
import optuna
import numpy as np

optuna.logging.set_verbosity(optuna.logging.WARNING)

# %% [markdown]
# # CB

# %%
selected_features = [
    'temp_of_extremities',    # Fitur 2
    'peripheral_pulse',       # Fitur 3
    'mucous_membrane',        # Fitur 4
    'pain',                   # Fitur 6
    'abdominal_distention',   # Fitur 8
    'rectal_exam_feces',      # Fitur 12
    'packed_cell_volume',     # Fitur 14
    'abdomo_appearance',      # Fitur 15
    'abdomo_protein',         # Fitur 16
    'surgical_lesion',        # Fitur 17
    'pulse_severity',         # Fitur 20
    'protein_severity',       # Fitur 21
    'pain_and_surgery',       # Fitur 23
    'dehydration_index',      # Fitur 24
    'vital_stress'            # Fitur 26
]

# %%
all_cat_cols = cat_cols + ordinal_cols

X_train_cb = X_train.copy()
X_val_cb = X_val.copy()
X_test_cb = test_fe.copy()

X_train_cb[all_cat_cols] = X_train_cb[all_cat_cols].fillna('missing').astype(str)
X_val_cb[all_cat_cols] = X_val_cb[all_cat_cols].fillna('missing').astype(str)
X_test_cb[all_cat_cols] = X_test_cb[all_cat_cols].fillna('missing').astype(str)

selcol_train = X_train_cb[selected_features]
selcol_val = X_val_cb[selected_features]
selcol_test = X_test_cb[selected_features]

updated_cat_features = [col for col in selected_features if col in all_cat_cols]

y_train_encoded_cb = le.fit_transform(y_train)
y_val_encoded_cb = le.transform(y_val)

# %%
# hasil selected_features didapat dari sini
sisa_cat_cols = [col for col in X_train_cb.columns if col in all_cat_cols]

model_imp = CatBoostClassifier(verbose=0)

# Daftarkan kolom kategorinya di sini!
model_imp.fit(X_train_cb, y_train_encoded_cb, cat_features=sisa_cat_cols)

# Ambil skor kepentingan fitur seperti biasa
importance_df = pd.DataFrame({
    'Feature': X_train_cb.columns,
    'Importance': model_imp.get_feature_importance()
}).sort_values(by='Importance', ascending=False)

# %%
importance_df
# Out:
#                   Feature  Importance
# 6                    pain    8.576621
# 12      rectal_exam_feces    7.851157
# 11  nasogastric_reflux_ph    6.629153
# 26           vital_stress    6.303505
# 24      dehydration_index    5.824591
# 4         mucous_membrane    5.476344
# 15      abdomo_appearance    4.923401
# 9        nasogastric_tube    4.711919
# 16         abdomo_protein    4.660294
# 8    abdominal_distention    4.587715
# 10     nasogastric_reflux    4.435774
# 3        peripheral_pulse    4.340339
# 21       protein_severity    3.943981
# 19         temp_deviation    3.888461
# 2     temp_of_extremities    3.486105
# 14     packed_cell_volume    3.392136
# 13                abdomen    3.167038
# 5   capillary_refill_time    2.943312
# 22         pulse_pcv_risk    2.611562
# 23       pain_and_surgery    2.088464
# 7             peristalsis    1.865609
# 18      has_strangulation    1.228505
# 17        surgical_lesion    0.928618
# 0                 surgery    0.773463
# ...

# %%
from catboost import CatBoostClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score
import numpy as np
import sklearn

def objective_cb(trial):
    params = {
        "iterations": trial.suggest_int("iterations", 400, 1200),
        "depth": trial.suggest_int("depth", 4, 8),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.1,log=True),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1, 10),
        "random_strength": trial.suggest_float("random_strength", 0.5, 5.0),
        "bagging_temperature": trial.suggest_float("bagging_temperature", 0, 3.0),
        "border_count": trial.suggest_int("border_count",32,255),
        "random_state": 42,
        "loss_function": "MultiClass",
        "auto_class_weights": "Balanced",
        "verbose": 0
    }

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    scores = []

    for train_idx, val_idx in skf.split(selcol_train, y_train_encoded_cb):
        # Bagi data fold
        X_tr, X_valid = selcol_train.iloc[train_idx], selcol_train.iloc[val_idx]
        y_tr, y_valid = y_train_encoded_cb[train_idx], y_train_encoded_cb[val_idx]

        model = CatBoostClassifier(**params)
        
        # Kirim data langsung ke model tanpa imputer atau SMOTE manual!
        model.fit(
            X_tr, y_tr,
            cat_features=updated_cat_features, # Daftarkan semua kolom kategori
            eval_set=(X_valid, y_valid),
            early_stopping_rounds=30,
            verbose=False
        )

        y_pred = model.predict(X_valid)
        scores.append(f1_score(y_valid, y_pred, average='macro'))

    return np.mean(scores)

# %%
study_cb = optuna.create_study(direction="maximize")
study_cb.optimize(objective_cb, n_trials=35)

# %%
# model
best_cb = CatBoostClassifier(
    **study_cb.best_params,
    loss_function="MultiClass",
    random_state=42,
    verbose=0
)

best_cb.fit(
    selcol_train, y_train_encoded_cb,
    cat_features=updated_cat_features,
    eval_set=(selcol_val, y_val_encoded_cb),
    early_stopping_rounds=30,
    verbose=False
)
# Out:
# CatBoostClassifier(bagging_temperature=0.5086235255503387, border_count=78, depth=5, iterations=670, l2_leaf_reg=3.0941497330597674, learning_rate=0.02032391478615701, loss_function='MultiClass', random_state=42, random_strength=1.9800235200455079, verbose=0)

# %%
# 4. Evaluasi
y_train_pred = best_cb.predict(selcol_train)
y_val_pred = best_cb.predict(selcol_val)

print("=== TRAIN CATBOOST ===")
print(classification_report(y_train_encoded_cb, y_train_pred, digits=4))

print("=== TEST CATBOOST ===")
print(classification_report(y_val_encoded_cb, y_val_pred, digits=4))
# Out:
# === TRAIN CATBOOST ===
#               precision    recall  f1-score   support
#
#            0     0.7119    0.7788    0.7438       330
#            1     0.7184    0.6281    0.6702       199
#            2     0.7969    0.7865    0.7917       459
#
#     accuracy                         0.7520       988
#    macro avg     0.7424    0.7311    0.7353       988
# weighted avg     0.7527    0.7520    0.7512       988
#
# === TEST CATBOOST ===
#               precision    recall  f1-score   support
#
#            0     0.6667    0.7500    0.7059        80
#            1     0.5778    0.5000    0.5361        52
#            2     0.6964    0.6783    0.6872       115
#
#     accuracy                         0.6640       247
#    macro avg     0.6470    0.6428    0.6431       247
# weighted avg     0.6618    0.6640    0.6614       247

# %% [markdown]
# ![image.png](attachment:5bf295e3-264d-46a3-bfd3-2767e3e03480.png)

# %% [markdown]
# # <a id='submission'>Make a submission</a>

# %%
test = best_xgb.predict(test_l_df)

# %%
# Write and run the above code in the following code section.
sample_submission = pd.read_csv("/kaggle/input/competitions/mkpdai-predict-health-outcomes-of-horses/sample_submission.csv")


outcome_mapping = {0: 'died', 1: 'euthanized', 2: 'lived'}
sample_submission['outcome'] = pd.Series(test).map(outcome_mapping)

# %%
# Write and run the above code in the following code section.

sample_submission
# Out:
#        id     outcome
# 0    1235       lived
# 1    1236        died
# 2    1237       lived
# 3    1238  euthanized
# 4    1239       lived
# ..    ...         ...
# 819  2054  euthanized
# 820  2055  euthanized
# 821  2056        died
# 822  2057       lived
# 823  2058       lived
#
# [824 rows x 2 columns]

# %%
# Write and run the above code in the following code section.
sample_submission.to_csv('submission.csv', index=False)

# %% [markdown]
# Submit to the competition by clicking on the **Submit to Competition** tab on the right of the screen. Then, click **Submit** button.
#
# To see the results, go to the **Leaderboard** tab in the competition page.
# https://www.kaggle.com/competitions/inbound-program-predict-health-outcomes-of-horses/leaderboard
#
# Or
#
# Click the **Output** tab on the right of the screen.  Then, right clicking on the three vertical dots of the CSV and click "More actions". Lastly, click the Download button.
#
# To submit your results to the leaderboard, go to the competition page (https://bit.ly/inbound-filkom) and click Submit Prediction button on the upper right.
#
# Upload the csv file and you have now successfully submitted to the competition!
#
# <a href="#0"><font size="1">Go to top</font></a>
